# %%
import pandas as pd
import re
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('cabal.csv', encoding = "cp1252")

# %%
df.tail()
# Out:
#       Unnamed: 0            date  \
# 5226        5226   April 9, 2013
# 5227        5227   April 8, 2013
# 5228        5228   April 2, 2013
# 5229        5229   April 1, 2013
# 5230        5230  March 30, 2013
#
#                                                headline  sponsored
# 5226  Why Should Nigerian Tech Companies Care About ...      False
# 5227                How Do You Hype A Brand Like Tecno?      False
# 5228  It’s Time To Start Telling The Stories That Ma...      False
# 5229     Jason’s Become A Lot More Talkative These Days      False
# 5230                   Jack Of All Code, Master Of None      False

# %%
# len(cabal[cabal['sponsored'] == True])

# %%
funding = df[df['headline'].str.lower().str.contains('raises|raised|raising|secures|closes|secured|closed')]

# %%
# funding

# %%
# len(funding)
# Out:
# 98

# %%
# funding

# %%
acquisition = df[df['headline'].str.lower().str.contains(("acquiring|acquired|acquiring|acquires"))]

# %%
len(acquisition)
# Out:
# 24

# %%
# acquisition['headline']

# %%
df[df['headline'].str.lower().str.contains(("seed funding|seed round|seed capital"))]
# Out:
#       Unnamed: 0                date  \
# 562          562   November 17, 2016
# 566          566   November 17, 2016
# 1328        1328      March 17, 2016
# 1636        1636   December 17, 2015
# 1732        1732    December 1, 2015
# 1774        1774   November 25, 2015
# 1808        1808   November 20, 2015
# 1825        1825   November 19, 2015
# 2087        2087    October 15, 2015
# 2327        2327   September 3, 2015
# 2379        2379     August 26, 2015
# 2794        2794       June 26, 2015
# 3735        3735   February 11, 2015
# 3743        3743   February 11, 2015
# 3996        3996     January 5, 2015
# 4150        4150    October 13, 2014
# 4789        4789      March 25, 2014
# 5056        5056  September 16, 2013
#
#                                                headline  sponsored
# 562   South African podcast platform, iono has raise...      False
# 566   Kenya’s WeFarm has raised $1.6 million in seed...      False
# ...

# %%
df[df['headline'].str.lower().str.contains(("closed"))]
# Out:
#       Unnamed: 0               date  \
# 75            75      June 27, 2018
# 583          583  November 15, 2016
# 1009        1009      June 28, 2016
# 1131        1131       May 13, 2016
# 1213        1213     April 19, 2016
# 1297        1297     March 23, 2016
# 1774        1774  November 25, 2015
# 2139        2139    October 6, 2015
# 2469        2469    August 12, 2015
# 2625        2625      July 21, 2015
# 3123        3123        May 6, 2015
#
#                                                headline  sponsored
# 75    Bitkoin Africa Has Secured An Undisclosed Amou...      False
# 583   Cactus Capital has invested an undisclosed amo...      False
# 1009                  WeChat has closed shop in Nigeria      False
# 1131  Singularity Investments just invested an undis...      False
# 1213  Singularity Investments backs Asoko Insight wi...      False
# 1297  Ringier and Silvertree have just acquired Deal...      False
# ...

# %%
df[df['headline'].str.lower().str.contains(("(?x)usd | USD"))]
# Out:
#       Unnamed: 0               date  \
# 2343        2343  September 1, 2015
# 2473        2473    August 12, 2015
# 2502        2502     August 6, 2015
# 2527        2527     August 3, 2015
# 2546        2546      July 30, 2015
# 2549        2549      July 30, 2015
# 2625        2625      July 21, 2015
# 3015        3015       May 25, 2015
# 3079        3079       May 12, 2015
# 3588        3588      March 2, 2015
# 3777        3777   February 6, 2015
# 3918        3918   January 19, 2015
# 3953        3953   January 13, 2015
#
#                                                headline  sponsored
# 2343  Here is why Fashola’s website costs 78 million...      False
# 2473  Convergence Invests USD 20 million In Venture ...      False
# 2502  PERA To Give Western Cape Entrepreneurs USD150...      False
# 2527  African Startups to Win USD150,000 at the 2016...      False
# 2546  Huge Group planning acquisitions in the range ...      False
# ...

# %%
funding[funding['headline'].str.lower().str.contains((""))]
# Out:
#       Unnamed: 0               date  \
# 2329        2329  September 3, 2015
# 2625        2625      July 21, 2015
# 2802        2802      June 25, 2015
# 3011        3011       May 25, 2015
#
#                                                headline  sponsored
# 2329  InVenture secures a $10 million series A to co...      False
# 2625  BitX has closed a USD 4 Million Series A led b...      False
# 2802  Andela Raises Series A Round of Funding From S...      False
# 3011  Exclusive: Hotels.ng Raises $1.2 Million Serie...      False

# %%
er = 'seed' & 'USD'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-dfb929addfdd> in <module>()
# ----> 1 er = 'seed' & 'USD'
#
# TypeError: unsupported operand type(s) for &: 'str' and 'str'

# %%
# funding['headline']
# pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

# %%
# pd.Series(funding['headline'], index=pd.date_range('1/1/2000', periods=len(funding['headline'])))

# %%
df.head()
# Out:
#    Unnamed: 0             date  \
# 0           0  August 10, 2018
# 1           1  August 10, 2018
# 2           2   August 9, 2018
# 3           3   August 8, 2018
# 4           4   August 8, 2018
#
#                                             headline  sponsored
# 0  Cameroon’s Silicon Mountain: Its History, Resi...      False
# 1  Can An Uptick In M&A Activity Affect The Afric...      False
# 2  Blogs, Websites and Social Media Posts; A lega...      False
# 3  Tecno Mobile Is Set To Thrill Fans with A Mega...       True
# 4  What You Should Know About Building An Edtech ...      False

# %%
# pd.to_datetime(df['date'])

# %%
time_index = pd.date_range('01/01/2010', periods=7, freq='M')

# %%
time_index
# Out:
# DatetimeIndex(['2010-01-31', '2010-02-28', '2010-03-31', '2010-04-30',
#                '2010-05-31', '2010-06-30', '2010-07-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
dta = pd.DataFrame(index=time_index)

# %%
dta
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5002463fb5cf> in <module>()
# ----> 1 dta
#
# NameError: name 'dta' is not defined

# %%
dta['Stock_Price'] = [1,2,3,4,5, np.nan, np.nan]

# %%
dta
# Out:
#             Stock_Price
# 2010-01-31          1.0
# 2010-02-28          2.0
# 2010-03-31          3.0
# 2010-04-30          4.0
# 2010-05-31          5.0
# 2010-06-30          NaN
# 2010-07-31          NaN

# %%
dta['lui'] = dta.rolling(window=2, center=True).count()

# %%
dta
# Out:
#             Stock_Price  lui
# 2010-01-31          1.0  1.0
# 2010-02-28          2.0  2.0
# 2010-03-31          3.0  2.0
# 2010-04-30          4.0  2.0
# 2010-05-31          5.0  2.0
# 2010-06-30          NaN  1.0
# 2010-07-31          NaN  0.0

# %%
dta['Stock_Price']
# Out:
# 2010-01-31    1.0
# 2010-02-28    2.0
# 2010-03-31    3.0
# 2010-04-30    4.0
# 2010-05-31    5.0
# 2010-06-30    NaN
# 2010-07-31    NaN
# Freq: M, Name: Stock_Price, dtype: float64

# %%
dta
# Out:
#             Stock_Price
# 2010-01-31          1.0
# 2010-02-28          2.0
# 2010-03-31          3.0
# 2010-04-30          4.0
# 2010-05-31          5.0
# 2010-06-30          NaN
# 2010-07-31          NaN

# %%
df.head(2
       )
# Out:
#    Unnamed: 0             date  \
# 0           0  August 10, 2018
# 1           1  August 10, 2018
#
#                                             headline  sponsored
# 0  Cameroon’s Silicon Mountain: Its History, Resi...      False
# 1  Can An Uptick In M&A Activity Affect The Afric...      False

# %%
df.groupby('headline')

# %%
df['dated'] = pd.to_datetime(df['date'])

# %%
funding.head()
# Out:
#      Unnamed: 0       date                                           headline  \
# 75           75 2018-06-27  Bitkoin Africa Has Secured An Undisclosed Amou...
# 79           79 2018-06-22  Itel Mobile Raises The Bar In Smartphone Batte...
# 173         173 2017-10-16  Building the future, with Kendall Ananyi: reac...
# 176         176 2017-10-10  BREAKING: Andela raises $40m from CRE VC, DBL,...
# 292         292 2017-05-24   Frontier Car Group Closes $22 Million Investment
#
#      sponsored
# 75       False
# 79        True
# 173      False
# 176      False
# 292      False

# %%
# funding.rolling(window=2).mean()

# %%
funds = funding.set_index('date')

# %%
# funds.rolling(window=).mean()

# %%
newDf = df.copy()

# %%
newDf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-af7a425d69e8> in <module>()
# ----> 1 newDf
#
# NameError: name 'newDf' is not defined

# %%
len(range(1, 4))
# Out:
# 3

# %%
df.head()
# Out:
#    Unnamed: 0             date  \
# 0           0  August 10, 2018
# 1           1  August 10, 2018
# 2           2   August 9, 2018
# 3           3   August 8, 2018
# 4           4   August 8, 2018
#
#                                             headline  sponsored      dated
# 0  Cameroon’s Silicon Mountain: Its History, Resi...      False 2018-08-10
# 1  Can An Uptick In M&A Activity Affect The Afric...      False 2018-08-10
# 2  Blogs, Websites and Social Media Posts; A lega...      False 2018-08-09
# 3  Tecno Mobile Is Set To Thrill Fans with A Mega...       True 2018-08-08
# 4  What You Should Know About Building An Edtech ...      False 2018-08-08

# %%
df['dated'] = pd.to_datetime(df['date'])

# %%
dates = pd.date_range(start='1/03/2013', end='1/08/2018')

# %%
type(dates)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
datesDf= pd.DataFrame(dates, columns=['dated'])

# %%
datesDf.merge(df, on='dated')
# Out:
#           dated  Unnamed: 0               date  \
# 0    2013-03-30        5230     March 30, 2013
# 1    2013-04-01        5229      April 1, 2013
# 2    2013-04-02        5228      April 2, 2013
# 3    2013-04-08        5227      April 8, 2013
# 4    2013-04-09        5226      April 9, 2013
# 5    2013-04-10        5225     April 10, 2013
# 6    2013-04-11        5224     April 11, 2013
# 7    2013-04-15        5223     April 15, 2013
# 8    2013-04-16        5220     April 16, 2013
# 9    2013-04-16        5221     April 16, 2013
# 10   2013-04-16        5222     April 16, 2013
# 11   2013-04-17        5219     April 17, 2013
# 12   2013-04-18        5218     April 18, 2013
# 13   2013-04-19        5217     April 19, 2013
# 14   2013-04-20        5216     April 20, 2013
# 15   2013-04-22        5215     April 22, 2013
# 16   2013-04-23        5214     April 23, 2013
# 17   2013-04-24        5212     April 24, 2013
# 18   2013-04-24        5213     April 24, 2013
# ...

# %%
df.tail(15)
# Out:
#       Unnamed: 0            date  \
# 5216        5216  April 20, 2013
# 5217        5217  April 19, 2013
# 5218        5218  April 18, 2013
# 5219        5219  April 17, 2013
# 5220        5220  April 16, 2013
# 5221        5221  April 16, 2013
# 5222        5222  April 16, 2013
# 5223        5223  April 15, 2013
# 5224        5224  April 11, 2013
# 5225        5225  April 10, 2013
# 5226        5226   April 9, 2013
# 5227        5227   April 8, 2013
# 5228        5228   April 2, 2013
# 5229        5229   April 1, 2013
# 5230        5230  March 30, 2013
#
#                                                headline  sponsored      dated
# 5216              Gameday At The Co-Creation Hub, Lagos      False 2013-04-20
# 5217                      Keep Calm And Make A Decision      False 2013-04-19
# 5218                                I’m Liking The iDEA      False 2013-04-18
# 5219  Why Is MTN Trying To Compete With Dropbox And ...      False 2013-04-17
# ...

# %%
len(df)
# Out:
# 5231

# %%
df['monthss'] = df['date'].apply(lambda x: x.strftime('%Y-%m'))

# %%
df.tail()
# Out:
#       Unnamed: 0       date  \
# 5226        5226 2013-04-09
# 5227        5227 2013-04-08
# 5228        5228 2013-04-02
# 5229        5229 2013-04-01
# 5230        5230 2013-03-30
#
#                                                headline  sponsored      dated  \
# 5226  Why Should Nigerian Tech Companies Care About ...      False 2013-04-09
# 5227                How Do You Hype A Brand Like Tecno?      False 2013-04-08
# 5228  It’s Time To Start Telling The Stories That Ma...      False 2013-04-02
# 5229     Jason’s Become A Lot More Talkative These Days      False 2013-04-01
# 5230                   Jack Of All Code, Master Of None      False 2013-03-30
#
#       count       month  monthss
# 5226      1  April-2013  2013-04
# 5227      1  April-2013  2013-04
# 5228      1  April-2013  2013-04
# 5229      1  April-2013  2013-04
# 5230      1  March-2013  2013-03

# %%
df['count'] = 1

# %%
df.set_index('date').groupby(['Code', 'ID']).resample('M', 'sum')

# %%
# df.groupby('date')['count'].sum()

# %%
df.tail()
# Out:
#       Unnamed: 0       date  \
# 5226        5226 2013-04-09
# 5227        5227 2013-04-08
# 5228        5228 2013-04-02
# 5229        5229 2013-04-01
# 5230        5230 2013-03-30
#
#                                                headline  sponsored      dated  \
# 5226  Why Should Nigerian Tech Companies Care About ...      False 2013-04-09
# 5227                How Do You Hype A Brand Like Tecno?      False 2013-04-08
# 5228  It’s Time To Start Telling The Stories That Ma...      False 2013-04-02
# 5229     Jason’s Become A Lot More Talkative These Days      False 2013-04-01
# 5230                   Jack Of All Code, Master Of None      False 2013-03-30
#
#       count       month
# 5226      1  April-2013
# 5227      1  April-2013
# 5228      1  April-2013
# 5229      1  April-2013
# 5230      1  March-2013

# %%
len(df.groupby(['month']).groups.keys())
# Out:
# 66

# %%
type(df.groupby('monthss')['count'].sum()
# Out:
# pandas.core.series.Series

# %%
sf = df.groupby('month')['date'].count()

# %%
chart a series
